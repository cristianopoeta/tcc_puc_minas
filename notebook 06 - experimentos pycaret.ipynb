# %% [markdown]
# <h1 style="background-color:black; color:white; padding:10px;">
#     Notebook 06 - Primeiros experimentos com PyCaret
# </h1>

# %% [markdown]
# Primeiros experimentos com PyCaret realizados em 3 ambientes diferentes:
#
# 1. Máquina Windows 10 - 64 bits, 16 GB RAM, 1 processador Intel Core i5-8365U (1.60GHz, 4 núcleos, 8 threads).
# 2. Google Colab ( https://colab.research.google.com/ ).
# 3. Servidor CentOS Linux 7 - 64 bits, 128 GB RAM, 32 processadores Intel Xeon E5-2620 v4 (2.10GHz, 8 núcleos, 16 threads).

# %% [markdown]
# <hr style="background-color:transparent;height:4px;border:none;border-top:2px solid #c0c0c0;border-bottom:2px solid #c0c0c0;">
#
# ### Definições iniciais

# %% [markdown]
# <hr style="height:0px;border:none;border-top:1px solid #c0c0c0;">
#
# - No Google Colab.

# %%
# !pip install pycaret

# %% [markdown]
# <hr style="height:0px;border:none;border-top:1px solid #c0c0c0;">
#
# - Habilitação de recarga de módulo editado.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# <hr style="height:0px;border:none;border-top:1px solid #c0c0c0;">
#
# - Pacotes de uso geral.

# %%
import sys
# import pycaret    # instalado com: pip install pycaret
import numpy as np
import pandas as pd
from pathlib import Path
from pycaret.regression import *
from IPython.display import Markdown

# Google Colab
from google.colab import drive
from pycaret.utils import enable_colab 
enable_colab()

# %% [markdown]
# <hr style="height:0px;border:none;border-top:1px solid #c0c0c0;">
#
# - Ajuste para módulos em diretórios fora de `sys.path`.

# %%
# máquina Windows 10
sys.path.append('d:/py_utils')

# Google Colab
nm_dir_gdrive = '/content/gdrive'
drive.mount(nm_dir_gdrive)
p_gdrive = Path(nm_dir_gdrive)
nm_dir_tcc = 'MyDrive/TCC_PUC_MG'
p_tcc = p_gdrive / nm_dir_tcc
sys.path.append(str(p_tcc))

# servidor Linux
p_user = Path('~').expanduser()
nm_dir_tcc = 'jup_ws/tcc'
p_tcc = p_user / nm_dir_tcc
sys.path.append(str(p_tcc))

# %% [markdown]
# <hr style="height:0px;border:none;border-top:1px solid #c0c0c0;">
#
# - Módulos em diretórios fora de `sys.path`.

# %%
import tcc
from pd_utils import (
    d_pd, exemplo_linha, resumo_tipos, resumo_categ, resumo_serie,
    DisplayPandas, ExemploLinha, ResumoTipos, ResumoCateg, ResumoSerie
)

# %% [markdown]
# <hr style="height:0px;border:none;border-top:1px solid #c0c0c0;">
#
# - Utilidades de exibição e resumo de objetos `pandas`.

# %%
# índice do primeiro elemento True de uma série boleana
# prim_true = lambda sr: sr[lambda s: s].index[0]

# %%
# índice do ultimo elemento True de uma série boleana
# ulti_true = lambda sr: sr[lambda s: s].index[-1]

# %%
# primeiro item, 4 items intermediárias, item final e dimensões de objeto pandas
# h1s4t1 = DisplayPandas(head=1, sample=4, tail=1)

# %%
# primeiro item, 1 items intermediário, item final e dimensões de objeto pandas
h1s1t1 = DisplayPandas(head=1, sample=1, tail=1)

# %% [markdown]
# <hr style="height:0px;border:none;border-top:1px solid #c0c0c0;">
#
# - Outras definições.

# %%
d = display
pdod = pd.options.display
pdoc = pd.option_context
pdod.precision = 2
pdod.max_columns = None

def print_expr(expr, sep='=', inv=False):
    if inv:
        print(f'{eval(expr)} {sep} {expr}')
    else:
        print(f'{expr} {sep} {eval(expr)}')

def print_rslt(expr, sep='-->', inv=True):
    print_expr(expr, sep, inv)

def teste_features(todas, alvo, cate, nume, igno):
    def p_r(e):
        nonlocal todas, alvo, cate, nume, igno
        print(f'{eval(e)} --> {e}')
    p_r( 'set(cate).isdisjoint( set(nume) )' )
    p_r( 'set(nume).isdisjoint( set(igno) )' )
    p_r( 'set(igno).isdisjoint( set(cate) )' )
    p_r( 'alvo not in ( set(cate) | set(nume) | set(igno) )' )
    p_r( 'set(todas) == ( {alvo} | set(cate) | set(nume) | set(igno) )' )

def d_dct(dct, tit_chave='chave', tit_valor='valor'):
    txt_md = f'{tit_chave}|{tit_valor}\n:--|:--'
    for chave, valor in dct.items():
        txt_md += f'\n{chave}|{valor!r}'
    display(Markdown(txt_md))

def salvar_experi(best_models):
    nomes = []
    data_hora = f'{datetime.now():%Y%m%d_%H%M%S}'
    nome = f'{data_hora}.pkl'
    save_config(nome)
    nomes.append(nome)
    for ind, model in enumerate(best_models, 1):
        nome = f'{data_hora}_{ind}_{model.__class__.__name__}'
        save_model(model, nome)
        nomes.append(nome)
    return nomes

# %% [markdown]
# <hr style="background-color:transparent;height:4px;border:none;border-top:2px solid #c0c0c0;border-bottom:2px solid #c0c0c0;">
#
# ### Importação de `df_vendas_bricks`

# %% [markdown]
# - Dataframe consolidado de vendas das peças de interesse com modificações do notebook 05 (arquivo `df_vendas_bricks_nb5.parquet`).
# - Colunas do dataframe:
# <table>
# <tr><th style="text-align:left;">Grupo</th><th>Coluna</th><th>Descrição</th></tr>
# <tr style="border-top:1px solid black;"><td rowspan=9 style="text-align:left;">Variáveis da linha de pedido (o = order):</td><td><code>o_itid</code></td><td>ID arbitrário da linha de pedido de peça</td></tr>
# <tr><td><code>p_no</code></td><td>código do modelo da peça</td></tr>
# <tr><td><code>c_id</code></td><td>código/ID da cor da peça</td></tr>
# <tr><td><code>n_u</code></td><td>estado da peça</td></tr>
# <tr><td><code>o_qtty</code></td><td>quantidade</td></tr>
# <tr><td><code>o_unpr</code></td><td>preço unitário em USD</td></tr>
# <tr><td><code>o_sctr</code></td><td>país do vendedor</td></tr>
# <tr><td><code>o_bctr</code></td><td>país do comprador</td></tr>
# <tr><td><code>o_dthr</code></td><td>data e hora do pedido</td></tr>
# <tr style="border-top:1px solid black;"><td rowspan=5 style="text-align:left;">Características físicas da peça comercializada (p = part)</td><td><code>p_wt</code></td><td>peso/massa em gramas</td></tr>
# <tr><td><code>p_dx</code></td><td>largura em studs</td></tr>
# <tr><td><code>p_dy</code></td><td>comprimento em studs</td></tr>
# <tr><td><code>p_dz</code></td><td>altura em bricks</td></tr>
# <tr><td><code>p_dv</code></td><td>volume externo em studs cúbicos</td></tr>
# <tr style="border-top:1px solid black;"><td rowspan=3 style="text-align:left;">Outros atributos da peça comercializada (p = part)</td><td><code>p_nm</code></td><td>nome do modelo de peça</td></tr>
# <tr><td><code>p_pfx</code></td><td>prefixo do código de modelo</td></tr>
# <tr><td><code>p_sfx</code></td><td>sufixo do código de modelo</td></tr>
# <tr style="border-top:1px solid black;"><td rowspan=3 style="text-align:left;">Atributos da cor da peça comercializada (c = color)</td><td><code>c_nm</code></td><td>nome da cor</td></tr>
# <tr><td><code>c_cd</code></td><td>código da cor (RGB 24 bits hexadecimal)</td></tr>
# <tr><td><code>c_tp</code></td><td>tipo/família da cor</td></tr>
# <tr style="border-top:1px solid black;"><td rowspan=3 style="text-align:left;">Métricas calculadas da linha do pedido (o = order):</td><td><code>o_ttpr</code></td><td>preço total em USD <code>o_qtty * o_unpr</code></td></tr>
# <tr><td><code>o_ttwt</code></td><td>peso/massa total em gramas <code>o_qtty * p_wt</code></td></tr>
# <tr><td><code>o_ttdv</code></td><td>volume externo total em studs cúbicos <code>o_qtty * p_dv</code></td></tr>
# <tr style="border-top:1px solid black;"><td rowspan=2 style="text-align:left;">Categorias calculadas (grp = grupo):</td><td><code>grp_dim</code></td><td>grupo de peças com mesmas dimensões externas</td></tr>
# <tr><td><code>grp_cor</code></td><td>grupo de cores adaptado do Studio 2.0</td></tr>
# </table>

# %%
nms_cols = [
    'p_no', 'c_id', 'n_u', 'o_qtty', 
    'o_unpr',    # variável alvo
    'o_sctr', 'o_bctr', 
    'o_dthr',    # aspecto temporal será ignorado (descartar)
    'p_wt', 'p_dx', 'p_dy', 'p_dz', 'p_dv', 
    'p_nm',    # descrição de `p_no` (descartar)
    'p_pfx', 'p_sfx',    # fragmentos de `p_no` (descartar)
    'c_nm',    # `c_nm` é descrição de `c_id` (descartar)
    'c_cd',    # `c_cd` como RGB hexadec texto não é útil (descartar)
    'c_tp', 
    'o_ttpr',    # métrica calculada com variável target (descartar)
    'o_ttwt', 'o_ttdv', 'grp_dim', 
    'grp_cor',    # grupos formados não refletem preços (descartar)
]    # nova ordem das colunas
df_vendas_bricks = (
    pd.read_parquet(tcc.pckl_df_vendas_bricks_nb5.with_suffix('.parquet'))
    [nms_cols]
)
h1s1t1(df_vendas_bricks)    # primeira linha, linha aleatória, última linha e dimensões
# Out:
#          p_no  c_id n_u  o_qtty  o_unpr o_sctr o_bctr                  o_dthr  \
# o_itid
# 40646    3005    80   N      20    0.10     DE     GB 2021-02-01 00:14:32.880
# 576403  14716    11   N       2    0.15     BE     BE 2021-04-04 23:39:49.673
# 770553   6213     6   U       2    6.06     DE     IL 2021-04-30 07:33:47.810
#
#          p_wt  p_dx  p_dy  p_dz  p_dv             p_nm  p_pfx p_sfx  c_nm  \
# o_itid
# 40646    0.44   1.0   1.0   1.0   1.2      Brick 1 x 1   3005          80
# 576403   1.24   1.0   1.0   3.0   3.6  Brick 1 x 1 x 3  14716          11
# 770553  10.18   2.0   6.0   3.0  43.2  Brick 2 x 6 x 3   6213           6
#
#           c_cd   c_tp  o_ttpr  o_ttwt  o_ttdv grp_dim  grp_cor
# o_itid
# 40646   2e5543  solid    1.94    8.80    24.0   1x1x1       12
# 576403  212121  solid    0.30    2.48     7.2   1x1x3       -1
# 770553  00642e  solid   12.12   20.36    86.4   2x6x3       12
# (1291936, 24)

# %% [markdown]
# <hr style="background-color:transparent;height:4px;border:none;border-top:2px solid #c0c0c0;border-bottom:2px solid #c0c0c0;">
#
# ### A - Experimento na máquina Windows 10

# %% [markdown]
# <hr style="background-color:transparent;height:0px;border:none;border-top:2px solid #c0c0c0;">
#
# #### A.1 - *Dataset* completo, *train size* de 20%, todas variáveis não consideradas dispensáveis
#
# - 7 variáveis categóricas, 8 variáveis numéricas.
# - *Dataset* original com dimensões (1291936, 24).
# - *Train set* processado com dimensões (258387, 350).
# - Várias horas de processamento, mas não anotadas (estimativa de mais de 12 horas).
# - Opções padrão do PyCaret para pré-processamento e treinamento (*cross validation* com 10 *folds*).

# %% [markdown]
# <hr style="height:0px;border:none;border-top:1px solid #c0c0c0;">
#
# - Escolha, classificação e conferência das variáveis.

# %%
target = 'o_unpr'
categorical_features = ['p_no', 'c_id', 'n_u', 'o_sctr', 'o_bctr', 'c_tp', 'grp_dim', ]
numeric_features = ['o_qtty', 'p_wt', 'p_dx', 'p_dy', 'p_dz', 'p_dv', 'o_ttwt', 'o_ttdv', ]
ignore_features = ['o_dthr', 'p_nm', 'p_pfx', 'p_sfx', 'c_nm', 'c_cd', 'o_ttpr', 'grp_cor']
teste_features(df_vendas_bricks.columns, target, 
               categorical_features, numeric_features, ignore_features)
# Out:
# True --> set(cate).isdisjoint( set(nume) )
# True --> set(nume).isdisjoint( set(igno) )
# True --> set(igno).isdisjoint( set(cate) )
# True --> alvo not in ( set(cate) | set(nume) | set(igno) )
# True --> set(todas) == ( {alvo} | set(cate) | set(nume) | set(igno) )

# %% [markdown]
# <hr style="height:0px;border:none;border-top:1px solid #c0c0c0;">
#
# - Configuração da regressão com PyCaret.

# %%
cfg_regress = setup(
    session_id=0, data=df_vendas_bricks, target=target, ignore_features=ignore_features, 
    categorical_features=categorical_features, numeric_features=numeric_features, 
    train_size = 0.2, silent=True, verbose=True, 
)
# Out:
# <style type="text/css">
# #T_99b59_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_99b59_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_99b59_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_99b59_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_99b59_row0_col1" class="data row0 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_99b59_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_99b59_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_99b59_row1_col1" class="data row1 col1" >o_unpr</td>
#     </tr>
#     <tr>
#       <th id="T_99b59_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_99b59_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_99b59_row2_col1" class="data row2 col1" >(1291936, 24)</td>
#     </tr>
#     <tr>
#       <th id="T_99b59_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_99b59_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_99b59_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_99b59_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_99b59_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_99b59_row4_col1" class="data row4 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_99b59_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_99b59_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_99b59_row5_col1" class="data row5 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_99b59_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_99b59_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_99b59_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_99b59_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_99b59_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_99b59_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_99b59_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_99b59_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_99b59_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_99b59_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_99b59_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_99b59_row9_col1" class="data row9 col1" >(258387, 350)</td>
#     </tr>
#     <tr>
#       <th id="T_99b59_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_99b59_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_99b59_row10_col1" class="data row10 col1" >(1033549, 350)</td>
#     </tr>
#     <tr>
#       <th id="T_99b59_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_99b59_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_99b59_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_99b59_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_99b59_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_99b59_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_99b59_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_99b59_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_99b59_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_99b59_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_99b59_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_99b59_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_99b59_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_99b59_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_99b59_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_99b59_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_99b59_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_99b59_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_99b59_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_99b59_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_99b59_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_99b59_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_99b59_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_99b59_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_99b59_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_99b59_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_99b59_row19_col1" class="data row19 col1" >c693</td>
#     </tr>
#     <tr>
#       <th id="T_99b59_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_99b59_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_99b59_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_99b59_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_99b59_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_99b59_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_99b59_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_99b59_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_99b59_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_99b59_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_99b59_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_99b59_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_99b59_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_99b59_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_99b59_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_99b59_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_99b59_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_99b59_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_99b59_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_99b59_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_99b59_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_99b59_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_99b59_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_99b59_row27_col1" class="data row27 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_99b59_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_99b59_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_99b59_row28_col1" class="data row28 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_99b59_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_99b59_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_99b59_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_99b59_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_99b59_row30_col0" class="data row30 col0" >Transformation Method</td>
#       <td id="T_99b59_row30_col1" class="data row30 col1" >None</td>
#     </tr>

# %% [markdown]
# <hr style="height:0px;border:none;border-top:1px solid #c0c0c0;">
#
# - Comparação dos resultados de *cross validation* dos modelos treinados com PyCaret.

# %%
best_models = compare_models(n_select=3)
# Out:
# <style type="text/css">
# #T_4e560_ th {
#   text-align: left;
# }
# #T_4e560_row0_col0, #T_4e560_row0_col2, #T_4e560_row1_col0, #T_4e560_row1_col1, #T_4e560_row1_col3, #T_4e560_row1_col4, #T_4e560_row1_col5, #T_4e560_row1_col6, #T_4e560_row2_col0, #T_4e560_row2_col1, #T_4e560_row2_col2, #T_4e560_row2_col3, #T_4e560_row2_col4, #T_4e560_row2_col5, #T_4e560_row2_col6, #T_4e560_row3_col0, #T_4e560_row3_col1, #T_4e560_row3_col2, #T_4e560_row3_col3, #T_4e560_row3_col4, #T_4e560_row3_col5, #T_4e560_row3_col6, #T_4e560_row4_col0, #T_4e560_row4_col1, #T_4e560_row4_col2, #T_4e560_row4_col3, #T_4e560_row4_col4, #T_4e560_row4_col5, #T_4e560_row4_col6, #T_4e560_row5_col0, #T_4e560_row5_col1, #T_4e560_row5_col2, #T_4e560_row5_col3, #T_4e560_row5_col4, #T_4e560_row5_col5, #T_4e560_row5_col6, #T_4e560_row6_col0, #T_4e560_row6_col1, #T_4e560_row6_col2, #T_4e560_row6_col3, #T_4e560_row6_col4, #T_4e560_row6_col5, #T_4e560_row6_col6, #T_4e560_row7_col0, #T_4e560_row7_col1, #T_4e560_row7_col2, #T_4e560_row7_col3, #T_4e560_row7_col4, #T_4e560_row7_col5, #T_4e560_row7_col6, #T_4e560_row8_col0, #T_4e560_row8_col1, #T_4e560_row8_col2, #T_4e560_row8_col3, #T_4e560_row8_col4, #T_4e560_row8_col5, #T_4e560_row8_col6, #T_4e560_row9_col0, #T_4e560_row9_col1, #T_4e560_row9_col2, #T_4e560_row9_col3, #T_4e560_row9_col4, #T_4e560_row9_col5, #T_4e560_row9_col6, #T_4e560_row10_col0, #T_4e560_row10_col1, #T_4e560_row10_col2, #T_4e560_row10_col3, #T_4e560_row10_col4, #T_4e560_row10_col5, #T_4e560_row10_col6, #T_4e560_row11_col0, #T_4e560_row11_col1, #T_4e560_row11_col2, #T_4e560_row11_col3, #T_4e560_row11_col4, #T_4e560_row11_col5, #T_4e560_row11_col6, #T_4e560_row12_col0, #T_4e560_row12_col1, #T_4e560_row12_col2, #T_4e560_row12_col3, #T_4e560_row12_col4, #T_4e560_row12_col5, #T_4e560_row12_col6, #T_4e560_row13_col0, #T_4e560_row13_col1, #T_4e560_row13_col2, #T_4e560_row13_col3, #T_4e560_row13_col4, #T_4e560_row13_col5, #T_4e560_row13_col6, #T_4e560_row14_col0, #T_4e560_row14_col1, #T_4e560_row14_col2, #T_4e560_row14_col3, #T_4e560_row14_col4, #T_4e560_row14_col5, #T_4e560_row14_col6, #T_4e560_row15_col0, #T_4e560_row15_col1, #T_4e560_row15_col2, #T_4e560_row15_col3, #T_4e560_row15_col4, #T_4e560_row15_col5, #T_4e560_row15_col6, #T_4e560_row16_col0, #T_4e560_row16_col1, #T_4e560_row16_col2, #T_4e560_row16_col3, #T_4e560_row16_col4, #T_4e560_row16_col5, #T_4e560_row16_col6 {
#   text-align: left;
# }
# #T_4e560_row0_col1, #T_4e560_row0_col3, #T_4e560_row0_col4, #T_4e560_row0_col5, #T_4e560_row0_col6, #T_4e560_row1_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_4e560_row0_col7, #T_4e560_row1_col7, #T_4e560_row2_col7, #T_4e560_row3_col7, #T_4e560_row4_col7, #T_4e560_row5_col7, #T_4e560_row6_col7, #T_4e560_row7_col7, #T_4e560_row8_col7, #T_4e560_row9_col7, #T_4e560_row10_col7, #T_4e560_row11_col7, #T_4e560_row12_col7, #T_4e560_row13_col7, #T_4e560_row15_col7, #T_4e560_row16_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_4e560_row14_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_4e560_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#       <th class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4e560_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_4e560_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_4e560_row0_col1" class="data row0 col1" >0.0519</td>
#       <td id="T_4e560_row0_col2" class="data row0 col2" >0.1347</td>
#       <td id="T_4e560_row0_col3" class="data row0 col3" >0.3433</td>
#       <td id="T_4e560_row0_col4" class="data row0 col4" >0.5446</td>
#       <td id="T_4e560_row0_col5" class="data row0 col5" >0.0768</td>
#       <td id="T_4e560_row0_col6" class="data row0 col6" >0.4105</td>
#       <td id="T_4e560_row0_col7" class="data row0 col7" >460.1740</td>
#     </tr>
#     <tr>
#       <th id="T_4e560_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_4e560_row1_col0" class="data row1 col0" >Extra Trees Regressor</td>
#       <td id="T_4e560_row1_col1" class="data row1 col1" >0.0538</td>
#       <td id="T_4e560_row1_col2" class="data row1 col2" >0.1331</td>
#       <td id="T_4e560_row1_col3" class="data row1 col3" >0.3436</td>
#       <td id="T_4e560_row1_col4" class="data row1 col4" >0.5355</td>
#       <td id="T_4e560_row1_col5" class="data row1 col5" >0.0796</td>
#       <td id="T_4e560_row1_col6" class="data row1 col6" >0.4250</td>
#       <td id="T_4e560_row1_col7" class="data row1 col7" >798.4670</td>
#     </tr>
#     <tr>
#       <th id="T_4e560_level0_row2" class="row_heading level0 row2" >dt</th>
#       <td id="T_4e560_row2_col0" class="data row2 col0" >Decision Tree Regressor</td>
#       <td id="T_4e560_row2_col1" class="data row2 col1" >0.0568</td>
#       <td id="T_4e560_row2_col2" class="data row2 col2" >0.1490</td>
#       <td id="T_4e560_row2_col3" class="data row2 col3" >0.3650</td>
#       <td id="T_4e560_row2_col4" class="data row2 col4" >0.4688</td>
#       <td id="T_4e560_row2_col5" class="data row2 col5" >0.0844</td>
#       <td id="T_4e560_row2_col6" class="data row2 col6" >0.4449</td>
#       <td id="T_4e560_row2_col7" class="data row2 col7" >8.0810</td>
#     </tr>
#     <tr>
#       <th id="T_4e560_level0_row3" class="row_heading level0 row3" >gbr</th>
#       <td id="T_4e560_row3_col0" class="data row3 col0" >Gradient Boosting Regressor</td>
#       <td id="T_4e560_row3_col1" class="data row3 col1" >0.0766</td>
#       <td id="T_4e560_row3_col2" class="data row3 col2" >0.1710</td>
#       <td id="T_4e560_row3_col3" class="data row3 col3" >0.3951</td>
#       <td id="T_4e560_row3_col4" class="data row3 col4" >0.3912</td>
#       <td id="T_4e560_row3_col5" class="data row3 col5" >0.1014</td>
#       <td id="T_4e560_row3_col6" class="data row3 col6" >0.7813</td>
#       <td id="T_4e560_row3_col7" class="data row3 col7" >75.6760</td>
#     </tr>
#     <tr>
#       <th id="T_4e560_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#       <td id="T_4e560_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_4e560_row4_col1" class="data row4 col1" >0.0638</td>
#       <td id="T_4e560_row4_col2" class="data row4 col2" >0.1791</td>
#       <td id="T_4e560_row4_col3" class="data row4 col3" >0.4058</td>
#       <td id="T_4e560_row4_col4" class="data row4 col4" >0.3714</td>
#       <td id="T_4e560_row4_col5" class="data row4 col5" >0.0904</td>
#       <td id="T_4e560_row4_col6" class="data row4 col6" >0.5548</td>
#       <td id="T_4e560_row4_col7" class="data row4 col7" >2.0420</td>
#     </tr>
#     <tr>
#       <th id="T_4e560_level0_row5" class="row_heading level0 row5" >knn</th>
#       <td id="T_4e560_row5_col0" class="data row5 col0" >K Neighbors Regressor</td>
#       <td id="T_4e560_row5_col1" class="data row5 col1" >0.0682</td>
#       <td id="T_4e560_row5_col2" class="data row5 col2" >0.1821</td>
#       <td id="T_4e560_row5_col3" class="data row5 col3" >0.4087</td>
#       <td id="T_4e560_row5_col4" class="data row5 col4" >0.3554</td>
#       <td id="T_4e560_row5_col5" class="data row5 col5" >0.1014</td>
#       <td id="T_4e560_row5_col6" class="data row5 col6" >0.5481</td>
#       <td id="T_4e560_row5_col7" class="data row5 col7" >27.0930</td>
#     </tr>
#     <tr>
#       <th id="T_4e560_level0_row6" class="row_heading level0 row6" >ridge</th>
#       <td id="T_4e560_row6_col0" class="data row6 col0" >Ridge Regression</td>
#       <td id="T_4e560_row6_col1" class="data row6 col1" >0.0796</td>
#       <td id="T_4e560_row6_col2" class="data row6 col2" >0.1991</td>
#       <td id="T_4e560_row6_col3" class="data row6 col3" >0.4337</td>
#       <td id="T_4e560_

# %% [markdown]
# <hr style="background-color:transparent;height:4px;border:none;border-top:2px solid #c0c0c0;border-bottom:2px solid #c0c0c0;">
#
# ### B - Experimentos no Google Colab

# %% [markdown]
# <hr style="background-color:transparent;height:0px;border:none;border-top:2px solid #c0c0c0;">
#
# #### B.1 - *Dataset* completo, *train size* de 20%, sem as variáveis `o_sctr` e `o_sctr`
#
# - 5 variáveis categóricas, 8 variáveis numéricas.
# - *Dataset* original com dimensões (1291936, 24).
# - *Train set* processado com dimensões (258387, 205).
# - Opções padrão do PyCaret para pré-processamento e treinamento (*cross validation* com 10 *folds*).

# %% [markdown]
# <hr style="height:0px;border:none;border-top:1px solid #c0c0c0;">
#
# - Escolha, classificação e conferência das variáveis.

# %%
target = 'o_unpr'
categorical_features = ['p_no', 'c_id', 'n_u', 'c_tp', 'grp_dim', ]
numeric_features = ['o_qtty', 'p_wt', 'p_dx', 'p_dy', 'p_dz', 'p_dv', 'o_ttwt', 'o_ttdv', ]
ignore_features = [
    'o_sctr', 'o_bctr',
    'o_dthr', 'p_nm', 'p_pfx', 'p_sfx', 'c_nm', 'c_cd', 'o_ttpr', 'grp_cor', 
]
teste_features(df_vendas_bricks.columns, target, 
               categorical_features, numeric_features, ignore_features)
# Out:
# True --> set(cate).isdisjoint( set(nume) )
# True --> set(nume).isdisjoint( set(igno) )
# True --> set(igno).isdisjoint( set(cate) )
# True --> alvo not in ( set(cate) | set(nume) | set(igno) )
# True --> set(todas) == ( {alvo} | set(cate) | set(nume) | set(igno) )

# %% [markdown]
# <hr style="height:0px;border:none;border-top:1px solid #c0c0c0;">
#
# - Configuração da regressão com PyCaret.

# %%
# %%time
cfg_regress = setup(
    session_id=0, data=df_vendas_bricks, target=target, ignore_features=ignore_features, 
    categorical_features=categorical_features, numeric_features=numeric_features, 
    train_size = 0.2, silent=True, verbose=True, 
)
# Out:
#                                Description             Value
# 0                               session_id                 0
# 1                                   Target            o_unpr
# 2                            Original Data     (1291936, 24)
# 3                           Missing Values             False
# 4                         Numeric Features                 8
# 5                     Categorical Features                 5
# 6                         Ordinal Features             False
# 7                High Cardinality Features             False
# 8                  High Cardinality Method              None
# 9                    Transformed Train Set     (258387, 205)
# 10                    Transformed Test Set    (1033549, 205)
# 11                      Shuffle Train-Test              True
# 12                     Stratify Train-Test             False
# 13                          Fold Generator             KFold
# 14                             Fold Number                10
# 15                                CPU Jobs                -1
# 16                                 Use GPU             False
# 17                          Log Experiment             False
# 18                         Experiment Name  reg-default-name
# 19                                     USI              f5a4
# 20                         Imputation Type            simple
# 21          Iterative Imputation Iteration              None
# 22                         Numeric Imputer              mean
# 23      Iterative Imputation Numeric Model              None
# 24                     Categorical Imputer          constant
# 25  Iterative Imputation Categorical Model              None
# 26           Unknown Categoricals Handling    least_frequent
# 27                               Normalize             False
# 28                        Normalize Method              None
# 29                          Transformation             False
# 30                   Transformation Method              None
# 31                                     PCA             False
# 32                              PCA Method              None
# 33                          PCA Components              None
# 34                     Ignore Low Variance             False
# 35                     Combine Rare Levels             False
# 36                    Rare Level Threshold              None
# 37                         Numeric Binning             False
# 38                         Remove Outliers             False
# 39                      Outliers Threshold              None
# 40                Remove Multicollinearity             False
# 41             Multicollinearity Threshold              None
# 42             Remove Perfect Collinearity              True
# 43                              Clustering             False
# 44                    Clustering Iteration              None
# 45                     Polynomial Features             False
# 46                       Polynomial Degree              None
# 47                    Trignometry Features             False
# 48                    Polynomial Threshold              None
# 49                          Group Features             False
# 50                       Feature Selection             False
# 51                Feature Selection Method           classic
# 52            Features Selection Threshold              None
# 53                     Feature Interaction             False
# 54                           Feature Ratio             False
# 55                   Interaction Threshold              None
# 56                        Transform Target             False
# 57                 Transform Target Method           box-cox
# CPU times: user 31.1 s, sys: 2.45 s, total: 33.5 s
# Wall time: 32.9 s

# %% [markdown]
# <hr style="height:0px;border:none;border-top:1px solid #c0c0c0;">
#
# - Comparação dos resultados de *cross validation* dos modelos treinados com PyCaret.

# %%
# %%time
best_models = compare_models(n_select=3)
# Out:
#                                     Model       MAE       MSE      RMSE  \
# rf                Random Forest Regressor  5.03e-02  1.29e-01  3.35e-01
# et                  Extra Trees Regressor  5.05e-02  1.32e-01  3.40e-01
# dt                Decision Tree Regressor  5.11e-02  1.33e-01  3.41e-01
# knn                 K Neighbors Regressor  5.98e-02  1.71e-01  3.94e-01
# gbr           Gradient Boosting Regressor  7.64e-02  1.69e-01  3.94e-01
# lightgbm  Light Gradient Boosting Machine  6.30e-02  1.82e-01  4.09e-01
# ridge                    Ridge Regression  7.82e-02  2.00e-01  4.34e-01
# br                         Bayesian Ridge  7.83e-02  2.08e-01  4.45e-01
# lr                      Linear Regression  8.36e-02  2.14e-01  4.51e-01
# omp           Orthogonal Matching Pursuit  8.69e-02  2.21e-01  4.59e-01
# huber                     Huber Regressor  7.79e-02  2.54e-01  4.92e-01
# en                            Elastic Net  1.08e-01  2.58e-01  4.95e-01
# lasso                    Lasso Regression  1.17e-01  2.64e-01  5.02e-01
# llar         Lasso Least Angle Regression  1.22e-01  2.68e-01  5.06e-01
# dummy                     Dummy Regressor  1.22e-01  2.68e-01  5.06e-01
# ada                    AdaBoost Regressor  9.95e-01  7.16e+00  1.75e+00
# par          Passive Aggressive Regressor  6.13e-01  8.56e+01  5.07e+00
# lar                Least Angle Regression  3.24e+24  1.74e+53  2.00e+26
#
#                 R2  RMSLE      MAPE  TT (Sec)
# rf        5.69e-01   0.07  4.11e-01    539.16
# et        5.48e-01   0.08  4.15e-01    681.85
# dt        5.40e-01   0.08  4.17e-01      7.87
# knn       4.03e-01   0.09  4.73e-01     49.36
# gbr       3.95e-01   0.10  7.79e-01    104.16
# lightgbm  3.59e-01   0.09  5.49e-01      2.77
# ridge     2.71e-01   0.10  7.06e-01      0.49
# br        2.31e-01   0.10  7.05e-01      9.43
# lr        2.09e-01   0.11  7.72e-01      2.88
# omp       1.80e-01   0.11  8.04e-01      0.57
# huber     6.18e-02   0.12  5.94e-01     45.73
# en        4.73e-02   0.13  1.25e+00      0.44
# lasso     1.82e-02   0.14  1.38e+00      0.42
# llar     -0.00e+00   0.15  1.44e+00      0.58
# dummy    -0.00e+00   0.15  1.44e+00      0.14
# ada      -1.96e+01   0.49  1.09e+01     78.32
# par      -2.79e+02   0.36  7.63e+00      2.83
# lar      -4.71e+53  42.22  2.71e+25      0.64
# CPU times: user 44min 47s, sys: 18.1 s, total: 45min 5s
# Wall time: 4h 36min 52s

# %% [markdown]
# <hr style="background-color:transparent;height:0px;border:none;border-top:2px solid #c0c0c0;">
#
# #### B.2 - Somente dados de jul/2021, *train size* de 20%, somente 2 variáveis categóricas (`c_id` e `n_u`)
#
# - 2 variáveis categóricas, 8 variáveis numéricas.
# - *Dataset* reduzido com dimensões (168832, 24).
# - *Train set* processado com dimensões (33766, 92).
# - Opções padrão do PyCaret para pré-processamento e treinamento (*cross validation* com 10 *folds*).

# %% [markdown]
# <hr style="height:0px;border:none;border-top:1px solid #c0c0c0;">
#
# - Escolha, classificação e conferência das variáveis.

# %%
target = 'o_unpr'
categorical_features = ['c_id', 'n_u', ]
numeric_features = ['o_qtty', 'p_wt', 'p_dx', 'p_dy', 'p_dz', 'p_dv', 'o_ttwt', 'o_ttdv', ]
ignore_features = [
    'p_no', 'grp_dim', 'o_sctr', 'o_bctr', 'c_tp', 
    'o_dthr', 'p_nm', 'p_pfx', 'p_sfx', 'c_nm', 'c_cd', 'o_ttpr', 'grp_cor', 
]
teste_features(df_vendas_bricks.columns, target, 
               categorical_features, numeric_features, ignore_features)
# Out:
# True --> set(cate).isdisjoint( set(nume) )
# True --> set(nume).isdisjoint( set(igno) )
# True --> set(igno).isdisjoint( set(cate) )
# True --> alvo not in ( set(cate) | set(nume) | set(igno) )
# True --> set(todas) == ( {alvo} | set(cate) | set(nume) | set(igno) )

# %% [markdown]
# <hr style="height:0px;border:none;border-top:1px solid #c0c0c0;">
#
# - Configuração da regressão com PyCaret.

# %%
# %%time
cfg_regress = setup(
    session_id=0, 
    data=df_vendas_bricks[lambda df: (df.o_dthr.dt.year==2021) & (df.o_dthr.dt.month==7)], 
            # somente linhas de de pedido de jul/2021
    target=target, ignore_features=ignore_features, 
    categorical_features=categorical_features, numeric_features=numeric_features, 
    train_size = 0.2, silent=True, verbose=True, 
)
# Out:
#                                Description             Value
# 0                               session_id                 0
# 1                                   Target            o_unpr
# 2                            Original Data      (168832, 24)
# 3                           Missing Values             False
# 4                         Numeric Features                 8
# 5                     Categorical Features                 2
# 6                         Ordinal Features             False
# 7                High Cardinality Features             False
# 8                  High Cardinality Method              None
# 9                    Transformed Train Set       (33766, 92)
# 10                    Transformed Test Set      (135066, 92)
# 11                      Shuffle Train-Test              True
# 12                     Stratify Train-Test             False
# 13                          Fold Generator             KFold
# 14                             Fold Number                10
# 15                                CPU Jobs                -1
# 16                                 Use GPU             False
# 17                          Log Experiment             False
# 18                         Experiment Name  reg-default-name
# 19                                     USI              e371
# 20                         Imputation Type            simple
# 21          Iterative Imputation Iteration              None
# 22                         Numeric Imputer              mean
# 23      Iterative Imputation Numeric Model              None
# 24                     Categorical Imputer          constant
# 25  Iterative Imputation Categorical Model              None
# 26           Unknown Categoricals Handling    least_frequent
# 27                               Normalize             False
# 28                        Normalize Method              None
# 29                          Transformation             False
# 30                   Transformation Method              None
# 31                                     PCA             False
# 32                              PCA Method              None
# 33                          PCA Components              None
# 34                     Ignore Low Variance             False
# 35                     Combine Rare Levels             False
# 36                    Rare Level Threshold              None
# 37                         Numeric Binning             False
# 38                         Remove Outliers             False
# 39                      Outliers Threshold              None
# 40                Remove Multicollinearity             False
# 41             Multicollinearity Threshold              None
# 42             Remove Perfect Collinearity              True
# 43                              Clustering             False
# 44                    Clustering Iteration              None
# 45                     Polynomial Features             False
# 46                       Polynomial Degree              None
# 47                    Trignometry Features             False
# 48                    Polynomial Threshold              None
# 49                          Group Features             False
# 50                       Feature Selection             False
# 51                Feature Selection Method           classic
# 52            Features Selection Threshold              None
# 53                     Feature Interaction             False
# 54                           Feature Ratio             False
# 55                   Interaction Threshold              None
# 56                        Transform Target             False
# 57                 Transform Target Method           box-cox
# CPU times: user 2.83 s, sys: 258 ms, total: 3.08 s
# Wall time: 3.04 s

# %% [markdown]
# <hr style="height:0px;border:none;border-top:1px solid #c0c0c0;">
#
# - Comparação dos resultados de *cross validation* dos modelos treinados com PyCaret.

# %%
# %%time
best_models = compare_models(n_select=3)
# Out:
#                                     Model   MAE      MSE   RMSE        R2  \
# gbr           Gradient Boosting Regressor  0.08     0.35   0.48  1.67e-01
# lightgbm  Light Gradient Boosting Machine  0.08     0.35   0.48  1.53e-01
# huber                     Huber Regressor  0.08     0.37   0.49  1.08e-01
# rf                Random Forest Regressor  0.06     0.36   0.48  8.64e-02
# et                  Extra Trees Regressor  0.06     0.36   0.48  7.71e-02
# en                            Elastic Net  0.11     0.37   0.50  7.04e-02
# knn                 K Neighbors Regressor  0.07     0.37   0.49  6.23e-02
# lasso                    Lasso Regression  0.12     0.38   0.51  1.44e-02
# dummy                     Dummy Regressor  0.12     0.38   0.51 -1.30e-03
# llar         Lasso Least Angle Regression  0.12     0.38   0.51 -1.30e-03
# ridge                    Ridge Regression  0.09     0.37   0.51 -1.69e-02
# dt                Decision Tree Regressor  0.06     0.37   0.50 -3.08e-02
# br                         Bayesian Ridge  0.09     0.38   0.51 -5.29e-02
# lr                      Linear Regression  0.09     0.38   0.51 -8.36e-02
# omp           Orthogonal Matching Pursuit  0.09     0.38   0.52 -1.02e-01
# ada                    AdaBoost Regressor  0.38     1.44   0.82 -1.97e+00
# lar                Least Angle Regression  0.10     0.90   0.75 -3.51e+00
# par          Passive Aggressive Regressor  3.99  4062.05  24.29 -3.58e+04
#
#           RMSLE   MAPE  TT (Sec)
# gbr        0.11   0.83      4.92
# lightgbm   0.11   0.76      0.35
# huber      0.12   0.72      3.34
# rf         0.10   0.55     32.28
# et         0.10   0.56     38.38
# en         0.14   1.42      0.05
# knn        0.12   0.68      0.76
# lasso      0.15   1.56      0.05
# dummy      0.15   1.59      0.03
# llar       0.15   1.59      0.05
# ridge      0.12   0.98      0.05
# dt         0.10   0.57      0.51
# br         0.12   0.98      0.37
# lr         0.12   1.01      0.43
# omp        0.13   0.98      0.05
# ada        0.25   5.24      1.53
# lar        0.13   0.99      0.07
# par        0.61  50.64      0.16
# CPU times: user 26 s, sys: 5.73 s, total: 31.7 s
# Wall time: 14min 12s

# %% [markdown]
# <hr style="background-color:transparent;height:4px;border:none;border-top:2px solid #c0c0c0;border-bottom:2px solid #c0c0c0;">
#
# ### C - Experimentos no servidor Linux

# %% [markdown]
# <hr style="background-color:transparent;height:0px;border:none;border-top:2px solid #c0c0c0;">
#
# #### C.1 - Somente dados de jul/2021, *train size* de 80%, sem as variáveis `grp_dim`, `o_sctr`, `o_bctr`
#
# - 4 variáveis categóricas, 8 variáveis numéricas.
# - *Dataset* reduzido com dimensões (168832, 24).
# - *Train set* processado com dimensões (135065, 177).
# - Opções padrão do PyCaret para pré-processamento e treinamento (*cross validation* com 10 *folds*).

# %% [markdown]
# <hr style="height:0px;border:none;border-top:1px solid #c0c0c0;">
#
# - Escolha, classificação e conferência das variáveis.

# %%
target = 'o_unpr'
categorical_features = ['p_no', 'c_id', 'n_u', 'c_tp', ]
numeric_features = ['o_qtty', 'p_wt', 'p_dx', 'p_dy', 'p_dz', 'p_dv', 'o_ttwt', 'o_ttdv', ]
ignore_features = [
    'grp_dim',  'o_sctr', 'o_bctr',
    'o_dthr', 'p_nm', 'p_pfx', 'p_sfx', 'c_nm', 'c_cd', 'o_ttpr', 'grp_cor', 
]
teste_features(df_vendas_bricks.columns, target, 
               categorical_features, numeric_features, ignore_features)
# Out:
# True --> set(cate).isdisjoint( set(nume) )
# True --> set(nume).isdisjoint( set(igno) )
# True --> set(igno).isdisjoint( set(cate) )
# True --> alvo not in ( set(cate) | set(nume) | set(igno) )
# True --> set(todas) == ( {alvo} | set(cate) | set(nume) | set(igno) )

# %% [markdown]
# <hr style="height:0px;border:none;border-top:1px solid #c0c0c0;">
#
# - Configuração da regressão com PyCaret.

# %%
# %%time
cfg_regress = setup(
    session_id=0, 
    data=df_vendas_bricks[lambda df: (df.o_dthr.dt.year==2021) & (df.o_dthr.dt.month==7)], 
            # somente linhas de de pedido de jul/2021
    target=target, ignore_features=ignore_features, 
    categorical_features=categorical_features, numeric_features=numeric_features, 
    train_size = 0.8, silent=True, verbose=True, 
)
# Out:
# <style  type="text/css" >
#     #T_2b3500ac_5244_11ec_a1b5_237061b81d69row42_col1 {
#             background-color:  lightgreen;
#         }</style><table id="T_2b3500ac_5244_11ec_a1b5_237061b81d69" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2b3500ac_5244_11ec_a1b5_237061b81d69level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_2b3500ac_5244_11ec_a1b5_237061b81d69row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_2b3500ac_5244_11ec_a1b5_237061b81d69row0_col1" class="data row0 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_2b3500ac_5244_11ec_a1b5_237061b81d69level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_2b3500ac_5244_11ec_a1b5_237061b81d69row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_2b3500ac_5244_11ec_a1b5_237061b81d69row1_col1" class="data row1 col1" >o_unpr</td>
#             </tr>
#             <tr>
#                         <th id="T_2b3500ac_5244_11ec_a1b5_237061b81d69level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_2b3500ac_5244_11ec_a1b5_237061b81d69row2_col0" class="data row2 col0" >Original Data</td>
#                         <td id="T_2b3500ac_5244_11ec_a1b5_237061b81d69row2_col1" class="data row2 col1" >(168832, 24)</td>
#             </tr>
#             <tr>
#                         <th id="T_2b3500ac_5244_11ec_a1b5_237061b81d69level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_2b3500ac_5244_11ec_a1b5_237061b81d69row3_col0" class="data row3 col0" >Missing Values</td>
#                         <td id="T_2b3500ac_5244_11ec_a1b5_237061b81d69row3_col1" class="data row3 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_2b3500ac_5244_11ec_a1b5_237061b81d69level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_2b3500ac_5244_11ec_a1b5_237061b81d69row4_col0" class="data row4 col0" >Numeric Features</td>
#                         <td id="T_2b3500ac_5244_11ec_a1b5_237061b81d69row4_col1" class="data row4 col1" >8</td>
#             </tr>
#             <tr>
#                         <th id="T_2b3500ac_5244_11ec_a1b5_237061b81d69level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_2b3500ac_5244_11ec_a1b5_237061b81d69row5_col0" class="data row5 col0" >Categorical Features</td>
#                         <td id="T_2b3500ac_5244_11ec_a1b5_237061b81d69row5_col1" class="data row5 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_2b3500ac_5244_11ec_a1b5_237061b81d69level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_2b3500ac_5244_11ec_a1b5_237061b81d69row6_col0" class="data row6 col0" >Ordinal Features</td>
#                         <td id="T_2b3500ac_5244_11ec_a1b5_237061b81d69row6_col1" class="data row6 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_2b3500ac_5244_11ec_a1b5_237061b81d69level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_2b3500ac_5244_11ec_a1b5_237061b81d69row7_col0" class="data row7 col0" >High Cardinality Features</td>
#                         <td id="T_2b3500ac_5244_11ec_a1b5_237061b81d69row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_2b3500ac_5244_11ec_a1b5_237061b81d69level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_2b3500ac_5244_11ec_a1b5_237061b81d69row8_col0" class="data row8 col0" >High Cardinality Method</td>
#                         <td id="T_2b3500ac_5244_11ec_a1b5_237061b81d69row8_col1" class="data row8 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_2b3500ac_5244_11ec_a1b5_237061b81d69level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_2b3500ac_5244_11ec_a1b5_237061b81d69row9_col0" class="data row9 col0" >Transformed Train Set</td>
#                         <td id="T_2b3500ac_5244_11ec_a1b5_237061b81d69row9_col1" class="data row9 col1" >(135065, 177)</td>
#             </tr>
#             <tr>
#                         <th id="T_2b3500ac_5244_11ec_a1b5_237061b81d69level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_2b3500ac_5244_11ec_a1b5_237061b81d69row10_col0" class="data row10 col0" >Transformed Test Set</td>
#                         <td id="T_2b3500ac_5244_11ec_a1b5_237061b81d69row10_col1" class="data row10 col1" >(33767, 177)</td>
#             </tr>
#             <tr>
#                         <th id="T_2b3500ac_5244_11ec_a1b5_237061b81d69level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_2b3500ac_5244_11ec_a1b5_237061b81d69row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#                         <td id="T_2b3500ac_5244_11ec_a1b5_237061b81d69row11_col1" class="data row11 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_2b3500ac_5244_11ec_a1b5_237061b81d69level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_2b3500ac_5244_11ec_a1b5_237061b81d69row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#                         <td id="T_2b3500ac_5244_11ec_a1b5_237061b81d69row12_col1" class="data row12 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_2b3500ac_5244_11ec_a1b5_237061b81d69level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_2b3500ac_5244_11ec_a1b5_237061b81d69row13_col0" class="data row13 col0" >Fold Generator</td>
#                         <td id="T_2b3500ac_5244_11ec_a1b5_237061b81d69row13_col1" class="data row13 col1" >KFold</td>
#             </tr>
#             <tr>
#                         <th id="T_2b3500ac_5244_11ec_a1b5_237061b81d69level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_2b3500ac_5244_11ec_a1b5_237061b81d69row14_col0" class="data row14 col0" >Fold Number</td>
#                         <td id="T_2b3500ac_5244_11ec_a1b5_237061b81d69row14_col1" class="data row14 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_2b3500ac_5244_11ec_a1b5_237061b81d69level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_2b3500ac_5244_11ec_a1b5_237061b81d69row15_col0" class="data row15 col0" >CPU Jobs</td>
#                         <td id="T_2b3500ac_5244_11ec_a1b5_237061b81d69row15_col1" class="data row15 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_2b3500ac_5244_11ec_a1b5_237061b81d69level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_2b3500ac_5244_11ec_a1b5_237061b81d69row16_col0" class="data row16 col0" >Use GPU</td>
#                         <td id="T_2b3500ac_5244_11ec_a1b5_237061b81d69row16_col1" class="data row16 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_2b3500ac_5244_11ec_a1b5_237061b81d69level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_2b3500ac_5244_11ec_a1b5_237061b81d69row17_col0" class="data row17 col0" >Log Experiment</td>
#                         <td id="T_2b3500ac_5244_11ec_a1b5_237061b81d69row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_2b3500ac_5244_11ec_a1b5_237061b81d69level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_2b3500ac_5244_11ec_a1b5_237061b81d69row18_col0" class="data row18 col0" >Experiment Name</td>
#                         <td id="T_2b3500ac_5244_11ec_a1b5_237061b81d69ro
# CPU times: user 5.55 s, sys: 4.06 s, total: 9.62 s
# Wall time: 4.64 s

# %% [markdown]
# <hr style="height:0px;border:none;border-top:1px solid #c0c0c0;">
#
# - Comparação dos resultados de *cross validation* dos modelos treinados com PyCaret.

# %%
# %%time
best_models = compare_models(n_select=3)
# Out:
# <style  type="text/css" >
#     #T_b87fc13a_5245_11ec_a1b5_237061b81d69 th {
#           text-align: left;
#     }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row0_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row0_col1 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row0_col2 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row0_col3 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row0_col4 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row0_col5 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row0_col6 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row0_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row1_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row1_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row1_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row1_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row1_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row1_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row1_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row1_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row2_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row2_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row2_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row2_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row2_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row2_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row2_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row2_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row3_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row3_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row3_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row3_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row3_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row3_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row3_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row3_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row4_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row4_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row4_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row4_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row4_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row4_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row4_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row4_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row5_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row5_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row5_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row5_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row5_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row5_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row5_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row5_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row6_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row6_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row6_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row6_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row6_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_b87fc13a_5245_11ec_a1b5_237061b81d69row6_col5 {
#             text-align:  left;
# CPU times: user 21min 15s, sys: 21.6 s, total: 21min 37s
# Wall time: 10min 51s

# %% [markdown]
# <hr style="background-color:transparent;height:0px;border:none;border-top:2px solid #c0c0c0;">
#
# #### C.2 - *Dataset* completo, *train size* de 50%, 5 variáveis categóricas, 8 variáveis numéricas, SEM outras opções de pré-processamento
#
# - 5 variáveis categóricas, 8 variáveis numéricas.
# - *Dataset* original com dimensões (1291936, 24).
# - *Train set* processado com dimensões (645968, 348).
# - Opções padrão do PyCaret para pré-processamento e treinamento, exceto:
#     - *cross validation* com 5 *folds* ;
#     - conjunto reduzido de modelos com melhores desempenhos nos experimentos anteriores .
# - Principais parâmetros do experimento no quadro resumo abaixo.

# %% [markdown]
# <hr style="height:0px;border:none;border-top:1px solid #c0c0c0;">
#
# - Escolha, classificação e conferência das variáveis.

# %%
target = 'o_unpr'
categorical_features = ['p_no', 'c_id', 'n_u', 'o_sctr', 'o_bctr', ]
numeric_features = ['p_wt', 'p_dx', 'p_dy', 'p_dz', 'p_dv', 'o_qtty', 'o_ttwt', 'o_ttdv', ]
ignore_features = [
    'grp_cor', 'c_tp', 'grp_dim', # cat
    # num
    'o_dthr', 'p_nm', 'p_pfx', 'p_sfx', 'c_nm', 'c_cd', 'o_ttpr', # sempre
]
teste_features(df_vendas_bricks.columns, target, 
               categorical_features, numeric_features, ignore_features)
# Out:
# True --> set(cate).isdisjoint( set(nume) )
# True --> set(nume).isdisjoint( set(igno) )
# True --> set(igno).isdisjoint( set(cate) )
# True --> alvo not in ( set(cate) | set(nume) | set(igno) )
# True --> set(todas) == ( {alvo} | set(cate) | set(nume) | set(igno) )

# %% [markdown]
# <hr style="height:0px;border:none;border-top:1px solid #c0c0c0;">
#
# - Configuração da regressão com PyCaret.

# %%
include = ['et','rf','knn','gbr','dt','lightgbm','ridge']
dct_compare_models = dict(n_select=3, fold=5, include=include)

dct_setup_1 = dict(
    session_id=0, data=df_vendas_bricks, silent=True, verbose=True, 
)

dct_setup_2 = dict(
    target=target, categorical_features=categorical_features, 
    numeric_features=numeric_features, ignore_features=ignore_features, 
)

dct_setup_3 = dict(  
    train_size = 0.5, 
)

# %%
# %%time
cfg_regress = setup(**{**dct_setup_1, **dct_setup_2, **dct_setup_3})
# Out:
# <style  type="text/css" >
#     #T_d6085f92_538e_11ec_864f_9b03c55d69d8row42_col1 {
#             background-color:  lightgreen;
#         }</style><table id="T_d6085f92_538e_11ec_864f_9b03c55d69d8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d6085f92_538e_11ec_864f_9b03c55d69d8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d6085f92_538e_11ec_864f_9b03c55d69d8row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_d6085f92_538e_11ec_864f_9b03c55d69d8row0_col1" class="data row0 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_d6085f92_538e_11ec_864f_9b03c55d69d8level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_d6085f92_538e_11ec_864f_9b03c55d69d8row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_d6085f92_538e_11ec_864f_9b03c55d69d8row1_col1" class="data row1 col1" >o_unpr</td>
#             </tr>
#             <tr>
#                         <th id="T_d6085f92_538e_11ec_864f_9b03c55d69d8level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_d6085f92_538e_11ec_864f_9b03c55d69d8row2_col0" class="data row2 col0" >Original Data</td>
#                         <td id="T_d6085f92_538e_11ec_864f_9b03c55d69d8row2_col1" class="data row2 col1" >(1291936, 24)</td>
#             </tr>
#             <tr>
#                         <th id="T_d6085f92_538e_11ec_864f_9b03c55d69d8level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_d6085f92_538e_11ec_864f_9b03c55d69d8row3_col0" class="data row3 col0" >Missing Values</td>
#                         <td id="T_d6085f92_538e_11ec_864f_9b03c55d69d8row3_col1" class="data row3 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_d6085f92_538e_11ec_864f_9b03c55d69d8level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_d6085f92_538e_11ec_864f_9b03c55d69d8row4_col0" class="data row4 col0" >Numeric Features</td>
#                         <td id="T_d6085f92_538e_11ec_864f_9b03c55d69d8row4_col1" class="data row4 col1" >8</td>
#             </tr>
#             <tr>
#                         <th id="T_d6085f92_538e_11ec_864f_9b03c55d69d8level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_d6085f92_538e_11ec_864f_9b03c55d69d8row5_col0" class="data row5 col0" >Categorical Features</td>
#                         <td id="T_d6085f92_538e_11ec_864f_9b03c55d69d8row5_col1" class="data row5 col1" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_d6085f92_538e_11ec_864f_9b03c55d69d8level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_d6085f92_538e_11ec_864f_9b03c55d69d8row6_col0" class="data row6 col0" >Ordinal Features</td>
#                         <td id="T_d6085f92_538e_11ec_864f_9b03c55d69d8row6_col1" class="data row6 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_d6085f92_538e_11ec_864f_9b03c55d69d8level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_d6085f92_538e_11ec_864f_9b03c55d69d8row7_col0" class="data row7 col0" >High Cardinality Features</td>
#                         <td id="T_d6085f92_538e_11ec_864f_9b03c55d69d8row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_d6085f92_538e_11ec_864f_9b03c55d69d8level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_d6085f92_538e_11ec_864f_9b03c55d69d8row8_col0" class="data row8 col0" >High Cardinality Method</td>
#                         <td id="T_d6085f92_538e_11ec_864f_9b03c55d69d8row8_col1" class="data row8 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_d6085f92_538e_11ec_864f_9b03c55d69d8level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_d6085f92_538e_11ec_864f_9b03c55d69d8row9_col0" class="data row9 col0" >Transformed Train Set</td>
#                         <td id="T_d6085f92_538e_11ec_864f_9b03c55d69d8row9_col1" class="data row9 col1" >(645968, 348)</td>
#             </tr>
#             <tr>
#                         <th id="T_d6085f92_538e_11ec_864f_9b03c55d69d8level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_d6085f92_538e_11ec_864f_9b03c55d69d8row10_col0" class="data row10 col0" >Transformed Test Set</td>
#                         <td id="T_d6085f92_538e_11ec_864f_9b03c55d69d8row10_col1" class="data row10 col1" >(645968, 348)</td>
#             </tr>
#             <tr>
#                         <th id="T_d6085f92_538e_11ec_864f_9b03c55d69d8level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_d6085f92_538e_11ec_864f_9b03c55d69d8row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#                         <td id="T_d6085f92_538e_11ec_864f_9b03c55d69d8row11_col1" class="data row11 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_d6085f92_538e_11ec_864f_9b03c55d69d8level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_d6085f92_538e_11ec_864f_9b03c55d69d8row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#                         <td id="T_d6085f92_538e_11ec_864f_9b03c55d69d8row12_col1" class="data row12 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_d6085f92_538e_11ec_864f_9b03c55d69d8level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_d6085f92_538e_11ec_864f_9b03c55d69d8row13_col0" class="data row13 col0" >Fold Generator</td>
#                         <td id="T_d6085f92_538e_11ec_864f_9b03c55d69d8row13_col1" class="data row13 col1" >KFold</td>
#             </tr>
#             <tr>
#                         <th id="T_d6085f92_538e_11ec_864f_9b03c55d69d8level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_d6085f92_538e_11ec_864f_9b03c55d69d8row14_col0" class="data row14 col0" >Fold Number</td>
#                         <td id="T_d6085f92_538e_11ec_864f_9b03c55d69d8row14_col1" class="data row14 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_d6085f92_538e_11ec_864f_9b03c55d69d8level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_d6085f92_538e_11ec_864f_9b03c55d69d8row15_col0" class="data row15 col0" >CPU Jobs</td>
#                         <td id="T_d6085f92_538e_11ec_864f_9b03c55d69d8row15_col1" class="data row15 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_d6085f92_538e_11ec_864f_9b03c55d69d8level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_d6085f92_538e_11ec_864f_9b03c55d69d8row16_col0" class="data row16 col0" >Use GPU</td>
#                         <td id="T_d6085f92_538e_11ec_864f_9b03c55d69d8row16_col1" class="data row16 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_d6085f92_538e_11ec_864f_9b03c55d69d8level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_d6085f92_538e_11ec_864f_9b03c55d69d8row17_col0" class="data row17 col0" >Log Experiment</td>
#                         <td id="T_d6085f92_538e_11ec_864f_9b03c55d69d8row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_d6085f92_538e_11ec_864f_9b03c55d69d8level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_d6085f92_538e_11ec_864f_9b03c55d69d8row18_col0" class="data row18 col0" >Experiment Name</td>
#                         <td id="T_d6085f92_538e_11ec_864f_9b03c55d69d8
# CPU times: user 48.5 s, sys: 20.9 s, total: 1min 9s
# Wall time: 52 s

# %% [markdown]
# <hr style="height:0px;border:none;border-top:1px solid #c0c0c0;">
#
# - Quadro resumo dos principais parâmetros do experimento.

# %%
d_dct({**dct_setup_2, **dct_setup_3}, tit_chave='parâmetro setup')
d_dct(dct_compare_models, tit_chave='parâmetro compare_models')
# Out:
# parâmetro setup|valor
# :--|:--
# target|'o_unpr'
# categorical_features|['p_no', 'c_id', 'n_u', 'o_sctr', 'o_bctr']
# numeric_features|['p_wt', 'p_dx', 'p_dy', 'p_dz', 'p_dv', 'o_qtty', 'o_ttwt', 'o_ttdv']
# ignore_features|['grp_cor', 'c_tp', 'grp_dim', 'o_dthr', 'p_nm', 'p_pfx', 'p_sfx', 'c_nm', 'c_cd', 'o_ttpr']
# train_size|0.5
# parâmetro compare_models|valor
# :--|:--
# n_select|3
# fold|5
# include|['et', 'rf', 'knn', 'gbr', 'dt', 'lightgbm', 'ridge']

# %% [markdown]
# <hr style="height:0px;border:none;border-top:1px solid #c0c0c0;">
#
# - Comparação dos resultados de *cross validation* dos modelos treinados com PyCaret.

# %%
# %%time
best_models = compare_models(**dct_compare_models)
# Out:
# <style  type="text/css" >
#     #T_23338ad0_5362_11ec_864f_9b03c55d69d8 th {
#           text-align: left;
#     }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row0_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row0_col1 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row0_col2 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row0_col3 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row0_col4 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row0_col5 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row0_col6 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row0_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row1_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row1_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row1_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row1_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row1_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row1_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row1_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row1_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row2_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row2_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row2_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row2_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row2_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row2_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row2_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row2_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row3_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row3_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row3_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row3_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row3_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row3_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row3_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row3_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row4_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row4_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row4_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row4_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row4_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row4_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row4_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row4_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row5_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row5_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row5_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row5_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row5_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row5_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row5_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row5_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row6_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row6_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row6_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row6_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row6_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_23338ad0_5362_11ec_864f_9b03c55d69d8row6_col5 {
#             text-align:  left;
# CPU times: user 10h 31min 53s, sys: 2min 25s, total: 10h 34min 19s
# Wall time: 1h 54min 20s

# %% [markdown]
# <hr style="background-color:transparent;height:0px;border:none;border-top:2px solid #c0c0c0;">
#
# #### C.3 - *Dataset* completo, *train size* de 60%, 5 variáveis categóricas, 8 variáveis numéricas, SEM outras opções de pré-processamento
#
# - 5 variáveis categóricas, 8 variáveis numéricas.
# - *Dataset* original com dimensões (1291936, 24).
# - *Train set* processado com dimensões (775161, 349).
# - Opções padrão do PyCaret para pré-processamento e treinamento, exceto:
#     - *cross validation* com 5 *folds* ;
#     - conjunto reduzido de modelos com melhores desempenhos nos experimentos anteriores .
# - Principais parâmetros do experimento no quadro resumo abaixo.

# %% [markdown]
# <hr style="height:0px;border:none;border-top:1px solid #c0c0c0;">
#
# - Escolha, classificação e conferência das variáveis.

# %%
target = 'o_unpr'
categorical_features = ['p_no', 'c_id', 'n_u', 'o_sctr', 'o_bctr', ]
numeric_features = ['p_wt', 'p_dx', 'p_dy', 'p_dz', 'p_dv', 'o_qtty', 'o_ttwt', 'o_ttdv', ]
ignore_features = [
    'grp_cor', 'c_tp', 'grp_dim', # cat
    # num
    'o_dthr', 'p_nm', 'p_pfx', 'p_sfx', 'c_nm', 'c_cd', 'o_ttpr', # sempre
]
teste_features(df_vendas_bricks.columns, target, 
               categorical_features, numeric_features, ignore_features)
# Out:
# True --> set(cate).isdisjoint( set(nume) )
# True --> set(nume).isdisjoint( set(igno) )
# True --> set(igno).isdisjoint( set(cate) )
# True --> alvo not in ( set(cate) | set(nume) | set(igno) )
# True --> set(todas) == ( {alvo} | set(cate) | set(nume) | set(igno) )

# %% [markdown]
# <hr style="height:0px;border:none;border-top:1px solid #c0c0c0;">
#
# - Configuração da regressão com PyCaret.

# %%
include = ['et','rf','gbr','dt','lightgbm','ridge']
dct_compare_models = dict(n_select=3, include=include)

dct_setup_1 = dict(
    session_id=0, data=df_vendas_bricks, silent=True, verbose=True, use_gpu=True, 
)

dct_setup_2 = dict(
    target=target, categorical_features=categorical_features, 
    numeric_features=numeric_features, ignore_features=ignore_features, 
)

dct_setup_3 = dict(  
    train_size = 0.6, fold=5, 
)

# %%
# %%time
cfg_regress = setup(**{**dct_setup_1, **dct_setup_2, **dct_setup_3})
# Out:
# <style  type="text/css" >
#     #T_339ac188_5392_11ec_864f_9b03c55d69d8row16_col1 {
#             background-color:  lightgreen;
#         }    #T_339ac188_5392_11ec_864f_9b03c55d69d8row42_col1 {
#             background-color:  lightgreen;
#         }</style><table id="T_339ac188_5392_11ec_864f_9b03c55d69d8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_339ac188_5392_11ec_864f_9b03c55d69d8level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_339ac188_5392_11ec_864f_9b03c55d69d8row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_339ac188_5392_11ec_864f_9b03c55d69d8row0_col1" class="data row0 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_339ac188_5392_11ec_864f_9b03c55d69d8level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_339ac188_5392_11ec_864f_9b03c55d69d8row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_339ac188_5392_11ec_864f_9b03c55d69d8row1_col1" class="data row1 col1" >o_unpr</td>
#             </tr>
#             <tr>
#                         <th id="T_339ac188_5392_11ec_864f_9b03c55d69d8level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_339ac188_5392_11ec_864f_9b03c55d69d8row2_col0" class="data row2 col0" >Original Data</td>
#                         <td id="T_339ac188_5392_11ec_864f_9b03c55d69d8row2_col1" class="data row2 col1" >(1291936, 24)</td>
#             </tr>
#             <tr>
#                         <th id="T_339ac188_5392_11ec_864f_9b03c55d69d8level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_339ac188_5392_11ec_864f_9b03c55d69d8row3_col0" class="data row3 col0" >Missing Values</td>
#                         <td id="T_339ac188_5392_11ec_864f_9b03c55d69d8row3_col1" class="data row3 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_339ac188_5392_11ec_864f_9b03c55d69d8level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_339ac188_5392_11ec_864f_9b03c55d69d8row4_col0" class="data row4 col0" >Numeric Features</td>
#                         <td id="T_339ac188_5392_11ec_864f_9b03c55d69d8row4_col1" class="data row4 col1" >8</td>
#             </tr>
#             <tr>
#                         <th id="T_339ac188_5392_11ec_864f_9b03c55d69d8level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_339ac188_5392_11ec_864f_9b03c55d69d8row5_col0" class="data row5 col0" >Categorical Features</td>
#                         <td id="T_339ac188_5392_11ec_864f_9b03c55d69d8row5_col1" class="data row5 col1" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_339ac188_5392_11ec_864f_9b03c55d69d8level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_339ac188_5392_11ec_864f_9b03c55d69d8row6_col0" class="data row6 col0" >Ordinal Features</td>
#                         <td id="T_339ac188_5392_11ec_864f_9b03c55d69d8row6_col1" class="data row6 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_339ac188_5392_11ec_864f_9b03c55d69d8level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_339ac188_5392_11ec_864f_9b03c55d69d8row7_col0" class="data row7 col0" >High Cardinality Features</td>
#                         <td id="T_339ac188_5392_11ec_864f_9b03c55d69d8row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_339ac188_5392_11ec_864f_9b03c55d69d8level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_339ac188_5392_11ec_864f_9b03c55d69d8row8_col0" class="data row8 col0" >High Cardinality Method</td>
#                         <td id="T_339ac188_5392_11ec_864f_9b03c55d69d8row8_col1" class="data row8 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_339ac188_5392_11ec_864f_9b03c55d69d8level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_339ac188_5392_11ec_864f_9b03c55d69d8row9_col0" class="data row9 col0" >Transformed Train Set</td>
#                         <td id="T_339ac188_5392_11ec_864f_9b03c55d69d8row9_col1" class="data row9 col1" >(775161, 349)</td>
#             </tr>
#             <tr>
#                         <th id="T_339ac188_5392_11ec_864f_9b03c55d69d8level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_339ac188_5392_11ec_864f_9b03c55d69d8row10_col0" class="data row10 col0" >Transformed Test Set</td>
#                         <td id="T_339ac188_5392_11ec_864f_9b03c55d69d8row10_col1" class="data row10 col1" >(516775, 349)</td>
#             </tr>
#             <tr>
#                         <th id="T_339ac188_5392_11ec_864f_9b03c55d69d8level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_339ac188_5392_11ec_864f_9b03c55d69d8row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#                         <td id="T_339ac188_5392_11ec_864f_9b03c55d69d8row11_col1" class="data row11 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_339ac188_5392_11ec_864f_9b03c55d69d8level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_339ac188_5392_11ec_864f_9b03c55d69d8row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#                         <td id="T_339ac188_5392_11ec_864f_9b03c55d69d8row12_col1" class="data row12 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_339ac188_5392_11ec_864f_9b03c55d69d8level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_339ac188_5392_11ec_864f_9b03c55d69d8row13_col0" class="data row13 col0" >Fold Generator</td>
#                         <td id="T_339ac188_5392_11ec_864f_9b03c55d69d8row13_col1" class="data row13 col1" >KFold</td>
#             </tr>
#             <tr>
#                         <th id="T_339ac188_5392_11ec_864f_9b03c55d69d8level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_339ac188_5392_11ec_864f_9b03c55d69d8row14_col0" class="data row14 col0" >Fold Number</td>
#                         <td id="T_339ac188_5392_11ec_864f_9b03c55d69d8row14_col1" class="data row14 col1" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_339ac188_5392_11ec_864f_9b03c55d69d8level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_339ac188_5392_11ec_864f_9b03c55d69d8row15_col0" class="data row15 col0" >CPU Jobs</td>
#                         <td id="T_339ac188_5392_11ec_864f_9b03c55d69d8row15_col1" class="data row15 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_339ac188_5392_11ec_864f_9b03c55d69d8level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_339ac188_5392_11ec_864f_9b03c55d69d8row16_col0" class="data row16 col0" >Use GPU</td>
#                         <td id="T_339ac188_5392_11ec_864f_9b03c55d69d8row16_col1" class="data row16 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_339ac188_5392_11ec_864f_9b03c55d69d8level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_339ac188_5392_11ec_864f_9b03c55d69d8row17_col0" class="data row17 col0" >Log Experiment</td>
#                         <td id="T_339ac188_5392_11ec_864f_9b03c55d69d8row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_339ac188_5392_11ec_864f_9b03c55d69d8level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_339ac188_5392_11ec_864f_9b03c55d69d8row18_col0" class="dat
# CPU times: user 1min 4s, sys: 19.7 s, total: 1min 23s
# Wall time: 48.8 s

# %% [markdown]
# <hr style="height:0px;border:none;border-top:1px solid #c0c0c0;">
#
# - Quadro resumo dos principais parâmetros do experimento.

# %%
d_dct({**dct_setup_2, **dct_setup_3}, tit_chave='parâmetro setup')
d_dct(dct_compare_models, tit_chave='parâmetro compare_models')
# Out:
# parâmetro setup|valor
# :--|:--
# target|'o_unpr'
# categorical_features|['p_no', 'c_id', 'n_u', 'o_sctr', 'o_bctr']
# numeric_features|['p_wt', 'p_dx', 'p_dy', 'p_dz', 'p_dv', 'o_qtty', 'o_ttwt', 'o_ttdv']
# ignore_features|['grp_cor', 'c_tp', 'grp_dim', 'o_dthr', 'p_nm', 'p_pfx', 'p_sfx', 'c_nm', 'c_cd', 'o_ttpr']
# train_size|0.6
# fold|5
# parâmetro compare_models|valor
# :--|:--
# n_select|3
# include|['et', 'rf', 'gbr', 'dt', 'lightgbm', 'ridge']

# %% [markdown]
# <hr style="height:0px;border:none;border-top:1px solid #c0c0c0;">
#
# - Comparação dos resultados de *cross validation* dos modelos treinados com PyCaret.

# %%
# %%time
best_models = compare_models(**dct_compare_models)
# Out:
# <style  type="text/css" >
#     #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8 th {
#           text-align: left;
#     }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row0_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row0_col1 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row0_col2 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row0_col3 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row0_col4 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row0_col5 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row0_col6 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row0_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row1_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row1_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row1_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row1_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row1_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row1_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row1_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row1_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row2_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row2_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row2_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row2_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row2_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row2_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row2_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row2_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row3_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row3_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row3_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row3_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row3_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row3_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row3_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row3_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row4_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row4_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row4_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row4_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row4_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row4_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row4_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row4_col7 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#             background-color:  lightgrey;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row5_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row5_col1 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row5_col2 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row5_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row5_col4 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row5_col5 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row5_col6 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_7fd812fc_53ac_11ec_864f_9b03c55d69d8row5_col7 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_7fd812fc_53ac_11ec_864f_9b03c55d69d8" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>        <th class="col_heading level0 col7" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7fd812fc_53ac_11ec_864f_9b03c55d69d8level0_row0" class="row_heading level0 row0" >rf</th>
#                         <td id="T_7fd812f
# CPU times: user 14h 9min 59s, sys: 6min 24s, total: 14h 16min 23s
# Wall time: 3h 2min 56s

# %%
salvar_experi(best_models)
# Out:
# Transformation Pipeline and Model Successfully Saved
# Transformation Pipeline and Model Successfully Saved
# Transformation Pipeline and Model Successfully Saved
# ['20211217_161835.pkl',
#  '20211217_161835_1_RandomForestRegressor',
#  '20211217_161835_2_ExtraTreesRegressor',
#  '20211217_161835_3_DecisionTreeRegressor']

# %%
list(Path().glob('20211217_161835*.pkl'))
# Out:
# [PosixPath('20211217_161835.pkl'),
#  PosixPath('20211217_161835_1_RandomForestRegressor.pkl'),
#  PosixPath('20211217_161835_2_ExtraTreesRegressor.pkl'),
#  PosixPath('20211217_161835_3_DecisionTreeRegressor.pkl')]
